# %% [markdown]
# # Part III: Model Training for Finger
#
#
# This tutorial is based on the [TensorFlow Image Classification](https://www.tensorflow.org/tutorials/images/classification) with some modifications, which shows how to classify images of fingerprints using a tf.keras.Sequential model and load data using tf.keras.utils.image_dataset_from_directory.
#
# This tutorial follows a basic machine learning workflow:
#
# 1. Examine and understand data
# 1. Build an input pipeline
# 1. Build the model
# 1. Train the model
# 1. Test the model
# 1. Improve the model and repeat the process
#
# The workflow above spans multiple notebooks
# 1. data exploration
# 1. data preprocessing
# 1. model training
# 1. model tuning

# %% [markdown]
# ## Setup
#
# Import TensorFlow and other necessary libraries:

# %%
! pip install -r ../requirements.txt -q

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import os
import cv2
import shutil

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from IPython.display import clear_output
# Out:
# 2023-11-20 20:38:44.589938: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-20 20:38:44.589991: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-20 20:38:44.590026: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-20 20:38:44.599580: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 20:38:45.937526: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Check TF and Cuda versions
#
# For reference [see this chart](https://www.tensorflow.org/install/source#gpu)

# %%
# check versions for Tensorflow and Cuda
print('TensorFlow: ' + tf.__version__)
print('TensorFlow Datasets: ' + tfds.__version__)
print('OpenCV version: ' + cv2.__version__)

# Check CUDA Version
sys_details = tf.sysconfig.get_build_info()
cuda_version = sys_details["cuda_version"]
print('Cuda version: ' + cuda_version)

# Check CUDNN Version
cudnn_version = sys_details["cudnn_version"]  
print('cudnn version: ' + cudnn_version)
# Out:
# TensorFlow: 2.14.0
# TensorFlow Datasets: 4.9.3
# OpenCV version: 4.8.1
# Cuda version: 11.8
# cudnn version: 8

# %%
# scratch directory is apart of the .gitignore to ensure it is not committed to git
# %env SCRATCH=../scratch
! [ -e "${SCRATCH}" ] || mkdir -p "${SCRATCH}"

scratch_path = os.environ.get('SCRATCH', './scratch')
# Out:
# env: SCRATCH=../scratch

# %% [markdown]
# # Before we create the dataset
#
# Lets move some images around and process them

# %%
# Define the source directories
source_directory_1 = os.path.join(os.environ["SCRATCH"], "train", "right")  # First source directory
source_directory_2 = os.path.join(os.environ["SCRATCH"], "train", "left")  # Second source directory

# Define the target directory
target_directory = os.path.join(os.environ["SCRATCH"], "train", "finger")  # Target directory

# Create the target directories for each category
categories = ['index', 'middle', 'ring', 'little', 'thumb']
category_counts = {category: 0 for category in categories}  # Initialize counts to zero

for category in categories:
    os.makedirs(os.path.join(target_directory, category), exist_ok=True)

# List files in the first source directory
files_1 = os.listdir(source_directory_1)

# List files in the second source directory
files_2 = os.listdir(source_directory_2)

# Combine files from both source directories
all_files = files_1 + files_2

# Copy files to the corresponding category directories and count them
for file in all_files:
    for category in categories:
        if category in file.lower():
            if file in files_1:
                source_path = os.path.join(source_directory_1, file)
            else:
                source_path = os.path.join(source_directory_2, file)
            target_path = os.path.join(target_directory, category, file)

            # Check if the source and target paths are different before copying
            if source_path != target_path:
                shutil.copy(source_path, target_path)
                category_counts[category] += 1

# Print the count of copied files for each category
for category, count in category_counts.items():
    print(f"Number of '{category}' files copied: {count}")
# Out:
# Number of 'index' files copied: 3595
# Number of 'middle' files copied: 3593
# Number of 'ring' files copied: 3587
# Number of 'little' files copied: 3592
# Number of 'thumb' files copied: 3586

# %% [markdown]
# ## Process the images

# %%
input_directory = scratch_path + "/train/finger"  # Replace with the path to your input directory
output_directory = scratch_path + "/processed/finger"  # Replace with the path to your output directory

# %%
# %run ../src/process_images.py

# %%
# run the function
process_images_in_directory(input_directory, output_directory)

clear_output()

# %% [markdown]
# # Create dataset
#
# Define some parameters for the loader

# %%
batch_size = 32
img_height = 96
img_width = 96

# %% [markdown]
# ## Create the training dataset

# %% [markdown]
# It's good practice to use a validation split when developing your model. Use 80% of the images for training and 20% for validation.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  scratch_path + '/processed/finger',
  #color_mode="grayscale",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 17953 files belonging to 5 classes.
# Using 14363 files for training.
# 2023-11-20 20:39:12.198474: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:12.198892: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:12.199238: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:12.199576: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.425312: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.425713: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.426054: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.426385: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.426716: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.427042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.427366: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:25.427688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.843705: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.844087: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.844499: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.844838: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.845175: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.845514: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.845850: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.846185: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.846518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.846853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.847187: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.847520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.879862: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.880311: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.880679: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.881035: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.881377: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.881716: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.882056: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.882386: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.882736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.883022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14791 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1b.0, compute capability: 7.0
# 2023-11-20 20:39:26.883438: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.883722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14791 MB memory:  -> device: 1, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1c.0, compute capability: 7.0
# 2023-11-20 20:39:26.884086: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.884399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 14791 MB memory:  -> device: 2, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1d.0, compute capability: 7.0
# 2023-11-20 20:39:26.884762: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-20 20:39:26.885042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 14791 MB memory:  -> device: 3, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0

# %% [markdown]
# ## Create the validation dataset

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  scratch_path + '/processed/finger',
  #color_mode="grayscale",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 17953 files belonging to 5 classes.
# Using 3590 files for validation.

# %% [markdown]
# ## Print the inferred class names

# %% [markdown]
# You can find the class names in the class_names attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['index', 'little', 'middle', 'ring', 'thumb']

# %% [markdown]
# ## Visualize the data
#
# Here are the first nine images from the training dataset with their corresponding labels.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Pass the datasets to the Keras Model.fit method for training in later steps.
#
# Use the image_batch tensor of  shape (32, 96, 96, 3), which splits batch of 32 images of shape 96x96x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 96, 96, 3)
# (32,)

# %% [markdown]
# ## Configure the dataset for performance
#
# We can use buffered prefetching, to yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# 1. `Dataset.cache` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# 1. `Dataset.prefetch` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')

# %%
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 4

# %%
# cuda_malloc_async has fewer fragmentation issues than the default BFC memory allocator - https://docs.nvidia.com/deeplearning/frameworks/tensorflow-user-guide/index.html#tf_gpu_allocator
TF_FORCE_GPU_ALLOW_GROWTH=True

os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
print(os.getenv("TF_GPU_ALLOCATOR"))
# Out:
# cuda_malloc_async

# %%
num_classes = len(class_names)
input_image_shape = (96, 96, 1)

with strategy.scope():
    model = Sequential([
      layers.Conv2D(16, 3, padding='same', activation='relu', input_shape=(img_height, img_width, 3), name='model'),
      layers.MaxPooling2D(),
      layers.Conv2D(32, 3, padding='same', activation='relu'),
      layers.MaxPooling2D(),
      layers.Conv2D(64, 3, padding='same', activation='relu'),
      layers.MaxPooling2D(),
      layers.Flatten(),
      layers.Dense(128, activation='relu'),
      layers.Dense(num_classes)
    ])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model (Conv2D)              (None, 96, 96, 16)        448
#
#  max_pooling2d (MaxPooling2  (None, 48, 48, 16)        0
#  D)
#
#  conv2d (Conv2D)             (None, 48, 48, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1204005 (4.59 MB)
# Trainable params: 1204005 (4.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs=10

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# INFO:tensorflow:Collective all_reduce tensors: 10 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Collective all_reduce tensors: 10 all_reduces, num_devices = 4, group_size = 4, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2023-11-20 20:39:42.037140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-20 20:39:42.038952: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-20 20:39:42.041573: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-20 20:39:42.043920: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-20 20:40:19.391322: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff174bbb1f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-20 20:40:19.391365: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2023-11-20 20:40:19.391373: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2023-11-20 20:40:19.391380: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2023-11-20 20:40:19.391385: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (3): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2023-11-20 20:40:19.401101: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-20 20:40:19.660403: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 444/449 [============================>.] - ETA: 0s - loss: 4.2358 - accuracy: 0.4585INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 449/449 [==============================] - 51s 13ms/step - loss: 4.2025 - accuracy: 0.4592 - val_loss: 1.1047 - val_accuracy: 0.5421
# Epoch 2/10
# 449/449 [==============================] - 5s 10ms/step - loss: 1.0310 - accuracy: 0.5839 - val_loss: 1.1675 - val_accuracy: 0.5373
# Epoch 3/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.8726 - accuracy: 0.6533 - val_loss: 1.0303 - val_accuracy: 0.5933
# Epoch 4/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.7279 - accuracy: 0.7154 - val_loss: 0.8841 - val_accuracy: 0.6565
# Epoch 5/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.5777 - accuracy: 0.7825 - val_loss: 0.9593 - val_accuracy: 0.6426
# Epoch 6/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.4436 - accuracy: 0.8338 - val_loss: 0.8550 - val_accuracy: 0.6769
# Epoch 7/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.3408 - accuracy: 0.8730 - val_loss: 0.9336 - val_accuracy: 0.6975
# Epoch 8/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.3287 - accuracy: 0.8797 - val_loss: 0.9399 - val_accuracy: 0.6916
# Epoch 9/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.2518 - accuracy: 0.9104 - val_loss: 1.1633 - val_accuracy: 0.6916
# Epoch 10/10
# 449/449 [==============================] - 5s 10ms/step - loss: 0.2364 - accuracy: 0.9143 - val_loss: 1.1590 - val_accuracy: 0.6836

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Serialize Model

# %%
# note: tf.saved_model.save(model, path_to_dir)
model_version = os.environ.get('VERSION', "1")


model_path = "../models/finger/" + model_version + "/model.savedmodel"
model.save(model_path)
# Out:
# INFO:tensorflow:Assets written to: ../models/finger/1/model.savedmodel/assets
# INFO:tensorflow:Assets written to: ../models/finger/1/model.savedmodel/assets

# %% [markdown]
# # Test with a sample

# %%
model_path = "../models/finger/" + model_version + "/model.savedmodel"
model = keras.models.load_model(model_path)

# %%
input_directory = scratch_path + "/real/"  # Replace with the path to your input directory
output_directory = scratch_path + "/processed/real/"  # Replace with the path to your output directory

# %%
# %run ../src/process_images.py

# %%
process_images_in_directory(input_directory, output_directory)

clear_output()

# %%
# select random images
import random
import matplotlib.pyplot as plt

samples_path = output_directory
file_list = os.listdir(samples_path)
print('Files in path: ' + str(len(file_list)))

test_image = random.choice(file_list)
print('Selected: ' + test_image)

# loads an image into PIL format.
img = tf.keras.utils.load_img(
    samples_path + test_image,
    #color_mode="grayscale",
    target_size=(img_height, img_width),
    #interpolation='nearest',
)

plt.imshow(img, cmap='gray')

# converts a PIL image instance to a numpy array
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
print("shape:",img_array.shape)
# Out:
# Files in path: 6000
# Selected: 3__M_Left_index_finger.png
# shape: (1, 96, 96, 3)

# %%
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image " + test_image + " is predicted as {} with a {:.2f} percent confidence. Prediction is " 
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

class_names[np.argmax(score)] in test_image
# Out:
# 1/1 [==============================] - 1s 851ms/step
# This image 3__M_Left_index_finger.png is predicted as thumb with a 84.93 percent confidence. Prediction is
# False

# %% [markdown]
# # Upload to S3

# %% [markdown]
# ## List the available buckets

# %%
# list objects using the aws s3 cli
! aws s3 ls
# Out:
# 2023-11-20 20:24:58 managed-velero-backups-736247ed-2c46-4068-825b-be42f54d5ac3
# 2023-11-16 22:36:17 rosa-n6wkj-cjkpb-image-registry-us-east-2-wbgvottmvhgatruvbiyd
# 2023-11-18 14:58:53 sagemaker-fingerprint-data-n6wkj

# %% [markdown]
# ## List the dynamically created bucket for the demo

# %%
import boto3

s3_client = boto3.client('s3')
response = s3_client.list_buckets()

filtered_buckets=[]

for bucket in response['Buckets']:
    bucket_name = bucket['Name']
    if bucket_name.startswith('sagemaker-fingerprint-'):
        filtered_buckets.append(bucket_name)
    
print(filtered_buckets)
# Out:
# ['sagemaker-fingerprint-data-n6wkj']

# %% [markdown]
# ## Upload the model to the demo bucket

# %%
import subprocess

for bucket in filtered_buckets:
    command = f"aws s3 sync ../models/finger s3://{bucket}/models/finger"
    subprocess.run(command, shell=True)
# Out:
# upload: ../models/finger/1/model.savedmodel/fingerprint.pb to s3://sagemaker-fingerprint-data-n6wkj/models/finger/1/model.savedmodel/fingerprint.pb
# upload: ../models/finger/1/model.savedmodel/variables/variables.index to s3://sagemaker-fingerprint-data-n6wkj/models/finger/1/model.savedmodel/variables/variables.index
# upload: ../models/finger/1/model.savedmodel/saved_model.pb to s3://sagemaker-fingerprint-data-n6wkj/models/finger/1/model.savedmodel/saved_model.pb
# upload: ../models/finger/1/model.savedmodel/keras_metadata.pb to s3://sagemaker-fingerprint-data-n6wkj/models/finger/1/model.savedmodel/keras_metadata.pb
# upload: ../models/finger/1/model.savedmodel/variables/variables.data-00000-of-00001 to s3://sagemaker-fingerprint-data-n6wkj/models/finger/1/model.savedmodel/variables/variables.data-00000-of-00001
