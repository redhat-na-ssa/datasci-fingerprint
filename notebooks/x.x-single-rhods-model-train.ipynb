# %% [markdown]
# # Fingerprint Left or Right Hand Prediction
#
# ## About the data
# Sokoto Coventry Fingerprint Dataset (SOCOFing) is a biometric fingerprint database designed for academic research purposes. SOCOFing is made up of 6,000 fingerprint images from 600 African subjects and contains unique attributes such as labels for gender, hand and finger name as well as synthetically altered versions with three different levels of alteration for obliteration, central rotation, and z-cut. For a complete formal description and usage policy please refer to the following paper: https://arxiv.org/abs/1807.10609.
#
# ## About the Demo
# This notebook was built to demonstrate the value of utilizing AWS SageMaker for Model development/training and Red Hat OpenShift on AWS for Model deployment/serving.
#
# ## About the notebook
# The intention of this notebook is to demonstrate steps from data ingestion to model saving that provides an accurate enough model that predicts if a fingerprint comes from a left or right hand. Coupled with other models that accurately predict finger and gender is valuable when matching against other identifiable information.
#
# 1. *Data Ingestion* [from object storage](#working-with-s3-buckets)
# 1. *Dataset preparation* (infer labels, splitting, augmenting, optimizing)
# 1. *Model Development* from scratch and *Training Strategies* (one device, mirrored, multi-worker mirrored)
# 1. *Model Performance* Hyperparameter Tuning strategies (RandomSearch, Hyperband, BayesianOptimization, Sklearn)
# 1. *Model Serialization* to object storage
# 1. *Prediction Sampling*
#
# ### Notebook Tested Requirements
#
# |Notebook origin|Notebook Customization|Instance Type|Kernel|TensorFlow|Runtime|
# |:-------|:-------|:-------|:-------|:-------|:-------|
# |SageMaker Notebook Instances|[from GitHub](https://github.com/redhat-na-ssa/demo-rosa-sagemaker/blob/main/sagemaker/lifecycle-from-github.sh)|ml.m5.4xlarge (vCPU: 16, RAM: 64 GiB)|conda_tensorflow2_p310|2.11|~120 minutes|
# |SageMaker Notebook Instances|[from GitHub](https://github.com/redhat-na-ssa/demo-rosa-sagemaker/blob/main/sagemaker/lifecycle-from-github.sh)|ml.p3.8xlarge (vCPU: 32, RAM: 244 GiB)|conda_tensorflow2_p310|2.11|~15 minutes|

# %% [markdown]
# # Setup

# %%
# source the setup Bash script to run specific configuration tasks
! source ../setup.sh && setup_dataset && install_requirements
# Out:
# You can run individual functions!
#
# example:
#   setup_demo
#
# Pulling dataset from https://github.com/redhat-na-ssa/datasci-fingerprint-data.git...
# exists
# tar: Ignoring unknown extended header keyword 'SCHILY.fflags'

# %%
# Install packages and frameworks
import tensorflow as tf
import os

# debugging code "Cleanup Called..." gets displayed if get_logger is not set
# the below code suppresses the "Cleanup Called..." output
tf.get_logger().setLevel('INFO')

# expecting 2.11
# if 2.7, than logging errors will show "Cleanup called..."
print(tf.__version__)
# Out:
# 2023-05-31 22:12:16.370048: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-31 22:12:16.504320: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-31 22:12:17.425799: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-05-31 22:12:17.425880: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-05-31 22:12:17.425890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.1

# %% [markdown]
# If this is your first time running the notebook, you may need to restart the kernel after the Tensorflow upgrade

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Create local directory structure
#
# - scratch: ignored by git; keep data out of git
# - models: saved models
# - real: "real" fingerprint samples
# - tune: hyperparameter trials results
# - train: decompressed training examples

# %%
# scratch directory is apart of the .gitignore to ensure it is not committed to git
# see setup.sh (setup_dataset)
# %env SCRATCH=../scratch
! [ -e "${SCRATCH}" ] || mkdir -p "${SCRATCH}"

scratch_path = os.environ.get('SCRATCH', './scratch')
# Out:
# env: SCRATCH=../scratch

# %% [markdown]
# ### Split the data into Train, Validation and Test
#
# Keras utility generates a dataset from image files in a directory and infers the labels based on the parent folder. This utility will return a tf.data.Dataset that yields batches of images from the subdirectories left and right
#
# ```
# train/
# ├── left/
# │   ├── a_image_1.jpg
# │   └── a_image_2.jpg
# └── right/
#     ├── b_image_1.jpg
#     └── b_image_2.jpg
# ```

# %%
# set variables for consistency
img_height = 96              # desired height
img_width = 96               # desired width
batch_size = 32              # batch inputs in 32
seed_train_validation = 42   # Must be same for train_ds and val_ds
validation_split = 0.3       # move 30% of the data into validation

# %% [markdown]
# ### Create Train
#
# Train is the sample of data used to fit the model.

# %%
# create the training dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    scratch_path + '/train',
    labels='inferred',
    label_mode = "categorical", 
    class_names=['left','right'],
    color_mode="grayscale",
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True, 
    seed=seed_train_validation,
    validation_split=validation_split,
    subset='training'
)
# Out:
# Found 17953 files belonging to 2 classes.
# Using 12568 files for training.
# 2023-05-31 22:12:20.232035: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:20.258737: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:20.260589: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:20.262963: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-31 22:12:20.265954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:20.267692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:20.269423: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:21.037993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:21.039695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:21.041140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-31 22:12:21.042534: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 546 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5

# %% [markdown]
# ### Create Validation
#
# Validation is the sample of data used to provide an unbiased evaluation of a model fit on the training dataset while tuning model hyperparameters. The evaluation becomes more biased as skill on the validation dataset is incorporated into the model configuration.

# %%
# create the validation dataset
validation_ds = tf.keras.preprocessing.image_dataset_from_directory(
    scratch_path + '/train',
    labels='inferred',
    label_mode = "categorical", 
    class_names=['left','right'],
    color_mode="grayscale",
    batch_size=batch_size,
    image_size=(img_height, img_width),
    shuffle=True, 
    seed=seed_train_validation,
    validation_split=validation_split,
    subset='validation'
)
# Out:
# Found 17953 files belonging to 2 classes.
# Using 5385 files for validation.

# %% [markdown]
# ## Create Test
#
# The sample of data used to provide an unbiased evaluation of a final model fit on the training dataset.

# %%
# create the test dataset
test_ds = validation_ds.take(16)
validation_ds = validation_ds.skip(16)

# %% [markdown]
# ## Print the Dataset batches

# %%
# reserves 393 batches training
print('70% of data in batches of 32 images for training -->', train_ds.cardinality())
# reserves 164 batches validation
print('20% of data in batches of 32 images for validating -->', validation_ds.cardinality())
# reserves 5 batches testing
print('10% of data in batches of 32 images for testing -->', test_ds.cardinality())
# Out:
# 70% of data in batches of 32 images for training --> tf.Tensor(393, shape=(), dtype=int64)
# 20% of data in batches of 32 images for validating --> tf.Tensor(153, shape=(), dtype=int64)
# 10% of data in batches of 32 images for testing --> tf.Tensor(16, shape=(), dtype=int64)

# %% [markdown]
# ## Print Inferred Dataset Classes

# %%
# display the class names inferred from the training dataset
class_names = train_ds.class_names
print(class_names)
# Out:
# ['left', 'right']

# %% [markdown]
# ## Print Fingerprint Data Samples

# %%
# show the first 10 images in the training dataset
from IPython.display import clear_output

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(10):
        ax = plt.subplot(5, 5, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"), cmap='gray')
        #TODO update labels
        #plt.title(int[labels[i]])
        plt.axis("off")
        
clear_output()

# %% [markdown]
# ## Apply augmentation
#
# When you don't have a large image dataset or when your images are all set in a single direction like ours are, it's a good practice to artificially introduce sample diversity by applying random, yet realistic, transformations to the training images, such as rotation and horizontal flipping. This helps expose the model to different aspects of the training data and reduce over-fitting.
#
# Learn more https://www.tensorflow.org/tutorials/images/data_augmentation

# %%
data_augmentation = tf.keras.Sequential([

  # randomly rotates images during training
  tf.keras.layers.RandomRotation(
    # a float represented as fraction of 2 Pi, or a tuple of size 2 representing lower and upper bound for rotating clockwise and counter-clockwise. 
    # A positive values means rotating counter clock-wise, while a negative value means clock-wise. 
    0.2,
      
    # Points outside the boundaries of the input are filled according to the given mode (one of {"constant", "reflect", "wrap", "nearest"}).
    fill_mode='constant',
      
    # Supported values: "nearest", "bilinear".
    interpolation='nearest',
      
    # Integer. Used to create a random seed.
    seed=None,
      
    # the value to be filled outside the boundaries when fill_mode="constant".
    fill_value=0.0,
),
])

# %% [markdown]
# Visualize a few augmented examples by applying data augmentation to the same image several times:Visualize a few augmented examples by applying data augmentation to the same image several times:

# %%
for image, _ in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[2]
  for i in range(10):
    ax = plt.subplot(5, 5, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 1, cmap='gray')
    plt.axis('off')
    
clear_output()

# %% [markdown]
# ## Configure the datasets for performance
#
# Let's make sure to use buffered prefetching so we can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data.
#
# 1. `Caching` a dataset, either in memory or on local storage. This will save some operations (like file opening and data reading) from being executed during each epoch.
# 1. `Prefetching` overlaps the preprocessing and model execution of a training step. While the model is executing training step s, the input pipeline is reading the data for step s+1. Doing so reduces the step time to the maximum (as opposed to the sum) of the training and the time it takes to extract the data.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
validation_ds = validation_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = validation_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Training

# %% [markdown]
# ## Define a training strategy
#
# tf.distribute.Strategy is a TensorFlow API to distribute training across multiple GPUs, multiple machines, or TPUs. Using this API, you can distribute your existing models and training code with minimal code changes.
# - Easy to use and support multiple user segments, including researchers, machine learning engineers, etc.
# - Provide good performance out of the box.
# - Easy switching between strategies.

# %%
# display physical devices
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# display logical devices
tf.config.list_logical_devices()
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'),
#  LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
#  example, single device
#device="/cpu:0"
device="/GPU:0"

#  example, multiple devices devices
#device = ['/device:GPU:0', '/device:GPU:1', '/device:GPU:2', '/device:GPU:3']

# %% [markdown]
# ### One Device Strategy
#
# A distribution strategy for running on a single device. Device string identifier for the device on which the variables should be placed. See class docs for more details on how the device is used. Examples: "/cpu:0", "/gpu:0", "/device:CPU:0", "/device:GPU:0"

# %%
# uncomment to create a OneDeviceStrategy

strategy = tf.distribute.OneDeviceStrategy(device=device)

# %% [markdown]
# ### Mirrored Strategy
#
# Supports synchronous distributed training on multiple GPUs on one machine. It creates one replica per GPU device. Each variable in the model is mirrored across all the replicas.

# %%
# uncomment to create a MirroredStrategy

#strategy = tf.distribute.MirroredStrategy(devices=device)
#strategy = tf.distribute.MirroredStrategy()

# %% [markdown]
# ### Multi-Worker Mirrored Strategy
#
# Multi-Worker MirroredStrategy is very similar to MirroredStrategy. It implements synchronous distributed training across multiple workers, each with potentially multiple GPUs. Similar to tf.distribute.MirroredStrategy, it creates copies of all variables in the model on each device across all workers.
#
# MultiWorkerMirroredStrategy has two implementations for cross-device communications.
# 1. CommunicationImplementation.RING is RPC-based and supports both CPUs and GPUs.
# 1. CommunicationImplementation.NCCL uses NCCL and provides state-of-art performance on GPUs but it doesn't support CPUs.
# 1. CollectiveCommunication.AUTO defers the choice to Tensorflow.
#
# You can specify them in the following way:

# %%
# uncomment to create a Multi-worker Mirrored Strategy

communication_options = tf.distribute.experimental.CommunicationOptions(
    # RING is RPC-based and supports both CPUs and GPUs.
    #implementation=tf.distribute.experimental.CommunicationImplementation.RING)

    # NCCL uses NCCL and provides state-of-art performance on GPUs but it doesn't support CPUs
    #implementation=tf.distribute.experimental.CommunicationImplementation.NCCL)
    
    # AUTO defers the choice to Tensorflow.
    implementation=tf.distribute.experimental.CommunicationImplementation.AUTO)

strategy = tf.distribute.MultiWorkerMirroredStrategy(communication_options=communication_options)

# %% [markdown]
# ## Define a model and hyperparameters
#
# When you build a model for hypertuning, you also define the hyperparameter search space in addition to the model architecture. The model you set up for hypertuning is called a hypermodel.

# %%
# build model from scratch
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Dropout,Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import layers
from tensorflow import keras
import keras_tuner as kt

num_classes = len(class_names)

inputShape=(img_height, img_width, 1)
data_format="channels_last"

def model_builder(hp):
    model = keras.Sequential(name="fingerprint_prediction")
    # comment out to remove augmentation
    data_augmentation
    input_shape=(img_height, img_width, 1)
    chanDim = -1
    # first CONV => RELU => POOL layer set
    model.add(Conv2D(
        hp.Int("conv_1", min_value=32, max_value=96, step=32),
        (3, 3), padding="same", input_shape=inputShape, data_format=data_format))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # second CONV => RELU => POOL layer set
    model.add(Conv2D(
        hp.Int("conv_2", min_value=64, max_value=128, step=32),
        (3, 3), padding="same", data_format=data_format))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # third CONV => RELU => POOL layer set
    model.add(Conv2D(
        hp.Int("conv_3", min_value=96, max_value=256, step=32),
        (3, 3), padding="same", data_format=data_format))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))    
    
    # first (and only) set of FC => RELU layers
    model.add(Flatten())
    model.add(Dense(hp.Int("dense_units", min_value=256,
                           max_value=768, step=256)))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    # softmax classifier
    model.add(Dense(num_classes))
    model.add(Activation("softmax"))
    
    # initialize the learning rate choices and optimizer
    lr = hp.Choice("learning_rate",
                   values=[1e-1, 1e-2, 1e-3])
    # compile the model
    model.compile(optimizer='adam', loss="categorical_crossentropy",
                  metrics=["accuracy"])
    # return the model
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.losses.CategoricalCrossentropy(from_logits=False),
        # metrics to be evaluated by the model during training and testing.The strings 'accuracy' or 'acc', TF converts this to binary, categorical or sparse.
        metrics=['accuracy'],
    )
    return model

# %% [markdown]
# ## Search hyperparameters
#
# The Keras Tuner has four tuners available:
# 1. RandomSearch
# 1. Hyperband
# 1. BayesianOptimization
# 1. Sklearn.
#
# In this tutorial, you use the Hyperband tuner.
#
# The Hyperband tuning algorithm uses adaptive resource allocation and early-stopping to quickly converge on a high-performing model. This is done using a sports championship style bracket. The algorithm trains a large number of models for a few epochs and carries forward only the top-performing half of models to the next round.
#
# To instantiate the Hyperband tuner, you must specify the hypermodel, the objective to optimize and the maximum number of epochs to train (max_epochs).

# %%
num_classes = len(class_names)

# open a strategy scope
tuner = kt.Hyperband(
    model_builder,
    objective='val_accuracy',
    # Integer, the maximum number of epochs to train one model. It is recommended to set this to a value slightly higher than the expected epochs to convergence for your largest Model, and to use early stopping during training
    max_epochs=5,
    # Integer, the reduction factor for the number of epochs and number of models for each bracket. Defaults to 3.
    factor=3,
    # training strategy
    distribution_strategy=strategy,
    # directory to save the hyperparameter trials
    # TODO Update with a variable
    directory=scratch_path + '/tune/model_hp',
    # folder to save the hyperparameter trail outputs
    project_name='hypertune',
    #  If you re-run the hyperparameter search, the Keras Tuner uses the existing state from these logs to resume the search. 
    # To disable this behavior, pass an additional overwrite=True argument while instantiating the tuner.
    overwrite=True
)

# %% [markdown]
# We’ll be using EarlyStopping to short circuit hyperparameter trials that are not performing well. Keep in mind that tuning hyperparameters is an extremely computationally expensive process, so if we can kill off poorly performing trials, we can save ourselves a bunch of time.

# %%
# stop training when a monitored metric has stopped improving
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode="auto")

# %% [markdown]
# This search will run for 10 Trials.
# - CPU: Best val_accuracy: 0.947070837020874  | Total elapsed time: 02h 11m 29s | Model: ?
# - GPU: Best val_accuracy: 0.872768342494964  | Total elapsed time: 00h 08m 44s | Sagemaker - Instance Type: ?
# - GPU: Best val_accuracy: 0.879129886627197  | Total elapsed time: 00h 59m 48s | Model: Tesla M10 (x4) | Driver Version: 525.60.13  |  CUDA Version: 12.0
#
# The learned values will be around
# ```
# [INFO] optimal number of filters in conv_1 layer: 32
# [INFO] optimal number of filters in conv_2 layer: 96
# [INFO] optimal number of filters in conv_3 layer: 160
# [INFO] optimal number of units in dense layer: 512
# [INFO] optimal learning rate: 0.0010
# ```

# %%
tuner.search(train_ds, epochs=4, validation_data=validation_ds, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print("[INFO] optimal number of filters in conv_1 layer: {}".format(
	best_hps.get("conv_1")))
print("[INFO] optimal number of filters in conv_2 layer: {}".format(
	best_hps.get("conv_2")))
print("[INFO] optimal number of filters in conv_3 layer: {}".format(
	best_hps.get("conv_3")))
print("[INFO] optimal number of units in dense layer: {}".format(
	best_hps.get("dense_units")))
print("[INFO] optimal learning rate: {:.4f}".format(
	best_hps.get("learning_rate")))
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# conv_1            |96                |?
# conv_2            |128               |?
# conv_3            |256               |?
# dense_units       |768               |?
# learning_rate     |0.1               |?
# tuner/epochs      |2                 |?
# tuner/initial_e...|0                 |?
# tuner/bracket     |1                 |?
# tuner/round       |0                 |?
#
# Epoch 1/2
# 2023-05-31 22:12:49.060963: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:784] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_1"
# op: "TensorSliceDataset"
# input: "Placeholder/_0"
# attr {
#   key: "Toutput_types"
#   value {
#     list {
#       type: DT_STRING
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: 12568
#   }
# }
# attr {
#   key: "is_files"
#   value {
#     b: false
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024TensorSliceDataset:0"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#       }
#     }
#   }
# }
# attr {
#   key: "replicate_on_split"
#   value {
#     b: false
#   }
# }
# experimental_type {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_DATASET
#     args {
#       type_id: TFT_PRODUCT
#       args {
#         type_id: TFT_TENSOR
#         args {
#           type_id: TFT_STRING
#         }
#       }
#     }
#   }
# }
#
# 2023-05-31 22:13:00.492834: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 108.00MiB (rounded to 113246208)requested by op fingerprint_prediction/activation/Relu
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-05-31 22:13:00.492882: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2023-05-31 22:13:00.492896: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 62, Chunks in use: 62. 15.5KiB allocated for chunks. 15.5KiB in use in bin. 1.1KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492906: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 22, Chunks in use: 22. 11.0KiB allocated for chunks. 11.0KiB in use in bin. 9.6KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492915: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 12, Chunks in use: 12. 12.8KiB allocated for chunks. 12.8KiB in use in bin. 12.0KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492924: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 14, Chunks in use: 14. 43.5KiB allocated for chunks. 43.5KiB in use in bin. 43.1KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492932: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 3, Chunks in use: 3. 18.0KiB allocated for chunks. 18.0KiB in use in bin. 18.0KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492941: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.492949: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.492957: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 1, Chunks in use: 1. 37.0KiB allocated for chunks. 37.0KiB in use in bin. 36.0KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492965: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.492973: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.492981: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 864.0KiB allocated for chunks. 864.0KiB in use in bin. 864.0KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492990: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 1, Chunks in use: 1. 846.0KiB allocated for chunks. 846.0KiB in use in bin. 432.0KiB client-requested in use in bin.
# 2023-05-31 22:13:00.492998: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 7, Chunks in use: 7. 8.58MiB allocated for chunks. 8.58MiB in use in bin. 7.88MiB client-requested in use in bin.
# 2023-05-31 22:13:00.493006: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.493014: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.493021: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.493029: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.493037: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.493046: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 3, Chunks in use: 2. 321.72MiB allocated for chunks. 216.00MiB in use in bin. 216.00MiB client-requested in use in bin.
# 2023-05-31 22:13:00.493055: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 1, Chunks in use: 1. 214.28MiB allocated for chunks. 214.28MiB in use in bin. 108.00MiB client-requested in use in bin.
# 2023-05-31 22:13:00.493062: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-05-31 22:13:00.493071: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 108.00MiB was 64.00MiB, Chunk State:
# 2023-05-31 22:13:00.493087: I tensorflow/tsl/framework/bfc_allocator.cc:1063]   Size: 105.72MiB | Requested Size: 0B | in_use: 0 | bin_num: 18, prev:   Size: 1.12MiB | Requested Size: 1.12MiB | in_use: 1 | bin_num: -1, next:   Size: 108.00MiB | Requested Size: 108.00MiB | in_use: 1 | bin_num: -1
# 2023-05-31 22:13:00.493097: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 572915712
# 2023-05-31 22:13:00.493108: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000000 of size 1280 next 1
# 2023-05-31 22:13:00.493115: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000500 of size 256 next 2
# 2023-05-31 22:13:00.493122: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000600 of size 256 next 3
# 2023-05-31 22:13:00.493129: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000700 of size 256 next 4
# 2023-05-31 22:13:00.493136: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000800 of size 256 next 5
# 2023-05-31 22:13:00.493142: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000900 of size 256 next 6
# 2023-05-31 22:13:00.493149: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000a00 of size 256 next 7
# 2023-05-31 22:13:00.493156: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000b00 of size 256 next 8
# 2023-05-31 22:13:00.493162: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000c00 of size 256 next 9
# 2023-05-31 22:13:00.493169: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000d00 of size 256 next 10
# 2023-05-31 22:13:00.493176: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000e00 of size 256 next 11
# 2023-05-31 22:13:00.493183: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810000f00 of size 256 next 12
# 2023-05-31 22:13:00.493189: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810001000 of size 256 next 13
# 2023-05-31 22:13:00.493196: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810001100 of size 1179648 next 14
# 2023-05-31 22:13:00.493205: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810121100 of size 1179648 next 15
# 2023-05-31 22:13:00.493212: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241100 of size 256 next 16
# 2023-05-31 22:13:00.493218: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241200 of size 256 next 22
# 2023-05-31 22:13:00.493225: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241300 of size 256 next 25
# 2023-05-31 22:13:00.493232: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241400 of size 256 next 28
# 2023-05-31 22:13:00.493239: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241500 of size 256 next 17
# 2023-05-31 22:13:00.493245: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241600 of size 256 next 19
# 2023-05-31 22:13:00.493252: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241700 of size 256 next 20
# 2023-05-31 22:13:00.493259: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241800 of size 256 next 18
# 2023-05-31 22:13:00.493265: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241900 of size 512 next 68
# 2023-05-31 22:13:00.493272: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241b00 of size 512 next 31
# 2023-05-31 22:13:00.493279: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241d00 of size 256 next 32
# 2023-05-31 22:13:00.493286: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241e00 of size 256 next 33
# 2023-05-31 22:13:00.493292: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810241f00 of size 512 next 27
# 2023-05-31 22:13:00.493299: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242100 of size 512 next 29
# 2023-05-31 22:13:00.493306: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242300 of size 256 next 23
# 2023-05-31 22:13:00.493313: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242400 of size 256 next 36
# 2023-05-31 22:13:00.493319: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242500 of size 512 next 30
# 2023-05-31 22:13:00.493326: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242700 of size 512 next 39
# 2023-05-31 22:13:00.493333: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242900 of size 256 next 40
# 2023-05-31 22:13:00.493342: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242a00 of size 256 next 41
# 2023-05-31 22:13:00.493361: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242b00 of size 512 next 38
# 2023-05-31 22:13:00.493368: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242d00 of size 512 next 37
# 2023-05-31 22:13:00.493375: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810242f00 of size 512 next 34
# 2023-05-31 22:13:00.493382: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243100 of size 256 next 44
# 2023-05-31 22:13:00.493388: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243200 of size 256 next 46
# 2023-05-31 22:13:00.493395: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243300 of size 256 next 54
# 2023-05-31 22:13:00.493402: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243400 of size 256 next 48
# 2023-05-31 22:13:00.493409: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243500 of size 256 next 49
# 2023-05-31 22:13:00.493415: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243600 of size 256 next 50
# 2023-05-31 22:13:00.493422: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243700 of size 1024 next 53
# 2023-05-31 22:13:00.493429: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243b00 of size 1024 next 55
# 2023-05-31 22:13:00.493436: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810243f00 of size 3072 next 57
# 2023-05-31 22:13:00.493443: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810244b00 of size 256 next 58
# 2023-05-31 22:13:00.493450: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810244c00 of size 256 next 59
# 2023-05-31 22:13:00.493457: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810244d00 of size 256 next 61
# 2023-05-31 22:13:00.493466: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810244e00 of size 256 next 62
# 2023-05-31 22:13:00.493473: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810244f00 of size 512 next 63
# 2023-05-31 22:13:00.493482: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810245100 of size 256 next 66
# 2023-05-31 22:13:00.493489: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810245200 of size 256 next 67
# 2023-05-31 22:13:00.493496: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810245300 of size 1024 next 47
# 2023-05-31 22:13:00.493503: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810245700 of size 1024 next 45
# 2023-05-31 22:13:00.493510: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810245b00 of size 1536 next 60
# 2023-05-31 22:13:00.493517: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810246100 of size 3584 next 69
# 2023-05-31 22:13:00.493524: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810246f00 of size 3072 next 51
# 2023-05-31 22:13:00.493531: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810247b00 of size 3072 next 56
# 2023-05-31 22:13:00.493539: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810248700 of size 3072 next 52
# 2023-05-31 22:13:00.493546: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810249300 of size 3072 next 70
# 2023-05-31 22:13:00.493553: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810249f00 of size 256 next 71
# 2023-05-31 22:13:00.493560: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a000 of size 256 next 72
# 2023-05-31 22:13:00.493568: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a100 of size 256 next 75
# 2023-05-31 22:13:00.493577: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a200 of size 256 next 73
# 2023-05-31 22:13:00.493584: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a300 of size 256 next 74
# 2023-05-31 22:13:00.493591: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a400 of size 256 next 78
# 2023-05-31 22:13:00.493598: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a500 of size 256 next 79
# 2023-05-31 22:13:00.493604: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a600 of size 512 next 82
# 2023-05-31 22:13:00.493612: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024a800 of size 512 next 83
# 2023-05-31 22:13:00.493621: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024aa00 of size 512 next 84
# 2023-05-31 22:13:00.493628: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024ac00 of size 512 next 26
# 2023-05-31 22:13:00.493635: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81024ae00 of size 37888 next 24
# 2023-05-31 22:13:00.493642: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810254200 of size 3584 next 80
# 2023-05-31 22:13:00.493650: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810255000 of size 3584 next 81
# 2023-05-31 22:13:00.493657: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810255e00 of size 512 next 85
# 2023-05-31 22:13:00.493664: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256000 of size 512 next 86
# 2023-05-31 22:13:00.493671: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256200 of size 512 next 88
# 2023-05-31 22:13:00.493679: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256400 of size 512 next 89
# 2023-05-31 22:13:00.493686: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256600 of size 512 next 90
# 2023-05-31 22:13:00.493693: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256800 of size 512 next 91
# 2023-05-31 22:13:00.493699: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256a00 of size 512 next 92
# 2023-05-31 22:13:00.493707: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256c00 of size 512 next 93
# 2023-05-31 22:13:00.493714: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810256e00 of size 1024 next 77
# 2023-05-31 22:13:00.493721: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810257200 of size 6144 next 76
# 2023-05-31 22:13:00.493731: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810258a00 of size 866304 next 21
# 2023-05-31 22:13:00.493738: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81032c200 of size 442368 next 35
# 2023-05-31 22:13:00.493745: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810398200 of size 442368 next 87
# 2023-05-31 22:13:00.493752: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd810404200 of size 1916928 next 42
# 2023-05-31 22:13:00.493760: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8105d8200 of size 1179648 next 43
# 2023-05-31 22:13:00.493768: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8106f8200 of size 113246208 next 100
# 2023-05-31 22:13:00.493778: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172f8200 of size 3072 next 101
# 2023-05-31 22:13:00.493786: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172f8e00 of size 3072 next 102
# 2023-05-31 22:13:00.493792: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172f9a00 of size 3072 next 103
# 2023-05-31 22:13:00.493799: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172fa600 of size 3072 next 104
# 2023-05-31 22:13:00.493808: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172fb200 of size 3072 next 105
# 2023-05-31 22:13:00.493816: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172fbe00 of size 3072 next 106
# 2023-05-31 22:13:00.493822: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172fca00 of size 6144 next 107
# 2023-05-31 22:13:00.493829: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172fe200 of size 6144 next 108
# 2023-05-31 22:13:00.493836: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172ffa00 of size 256 next 109
# 2023-05-31 22:13:00.493843: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172ffb00 of size 256 next 110
# 2023-05-31 22:13:00.493850: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172ffc00 of size 256 next 111
# 2023-05-31 22:13:00.493858: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172ffd00 of size 256 next 112
# 2023-05-31 22:13:00.493865: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172ffe00 of size 256 next 113
# 2023-05-31 22:13:00.493872: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd8172fff00 of size 256 next 114
# 2023-05-31 22:13:00.493879: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300000 of size 256 next 115
# 2023-05-31 22:13:00.493886: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300100 of size 256 next 116
# 2023-05-31 22:13:00.493895: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300200 of size 256 next 117
# 2023-05-31 22:13:00.493902: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300300 of size 256 next 118
# 2023-05-31 22:13:00.493909: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300400 of size 256 next 119
# 2023-05-31 22:13:00.493916: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300500 of size 256 next 120
# 2023-05-31 22:13:00.493926: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300600 of size 256 next 121
# 2023-05-31 22:13:00.493933: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817300700 of size 1179648 next 122
# 2023-05-31 22:13:00.493940: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817420700 of size 256 next 123
# 2023-05-31 22:13:00.493947: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817420800 of size 256 next 124
# 2023-05-31 22:13:00.493957: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817420900 of size 256 next 125
# 2023-05-31 22:13:00.493964: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817420a00 of size 256 next 126
# 2023-05-31 22:13:00.493971: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd817420b00 of size 1179648 next 127
# 2023-05-31 22:13:00.493977: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7fd817540b00 of size 110851840 next 65
# 2023-05-31 22:13:00.493986: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd81def8200 of size 113246208 next 64
# 2023-05-31 22:13:00.493993: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd824af8200 of size 1179648 next 94
# 2023-05-31 22:13:00.494001: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd824c18200 of size 1024 next 95
# 2023-05-31 22:13:00.494010: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd824c18600 of size 1024 next 96
# 2023-05-31 22:13:00.494017: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd824c18a00 of size 1024 next 97
# 2023-05-31 22:13:00.494023: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd824c18e00 of size 1024 next 98
# 2023-05-31 22:13:00.494032: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd824c19200 of size 1024 next 99
# 2023-05-31 22:13:00.494040: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fd824c19600 of size 224684544 next 18446744073709551615
# 2023-05-31 22:13:00.494047: I tensorflow/tsl/framework/bfc_allocator.cc:1095]      Summary of in-use Chunks by size:
# 2023-05-31 22:13:00.494059: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 62 Chunks of size 256 totalling 15.5KiB
# 2023-05-31 22:13:00.494067: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 22 Chunks of size 512 totalling 11.0KiB
# 2023-05-31 22:13:00.494075: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 10 Chunks of size 1024 totalling 10.0KiB
# 2023-05-31 22:13:00.494086: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-05-31 22:13:00.494093: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1536 totalling 1.5KiB
# 2023-05-31 22:13:00.494101: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 11 Chunks of size 3072 totalling 33.0KiB
# 2023-05-31 22:13:00.494109: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 3584 totalling 10.5KiB
# 2023-05-31 22:13:00.494119: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 6144 totalling 18.0KiB
# 2023-05-31 22:13:00.494127: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 37888 totalling 37.0KiB
# 2023-05-31 22:13:00.494135: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 442368 totalling 864.0KiB
# 2023-05-31 22:13:00.494146: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 866304 totalling 846.0KiB
# 2023-05-31 22:13:00.494153: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 6 Chunks of size 1179648 totalling 6.75MiB
# 2023-05-31 22:13:00.494161: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1916928 totalling 1.83MiB
# 2023-05-31 22:13:00.494172: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 113246208 totalling 216.00MiB
# 2023-05-31 22:13:00.494180: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 224684544 totalling 214.28MiB
# 2023-05-31 22:13:00.494187: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 440.66MiB
# 2023-05-31 22:13:00.494198: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 572915712 memory_limit_: 572915712 available bytes: 0 curr_region_allocation_bytes_: 1145831424
# 2023-05-31 22:13:00.494209: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                       572915712
# InUse:                       462063872
# MaxInUse:                    462063872
# NumAllocs:                         510
# MaxAllocSize:                224684544
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-05-31 22:13:00.494226: W tensorflow/tsl/framework/bfc_allocator.cc:492] **********************__________________*****************************************xxxxxxxxxxxxxxxxxxx
# 2023-05-31 22:13:00.494261: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at conv_ops_fused_impl.h:766 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,96,96,96] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tuner.search(train_ds, epochs=4, validation_data=validation_ds, callbacks=[stop_early])
#       3 # Get the optimal hyperparameters
#       4 best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File /opt/app-root/lib64/python3.9/site-packages/keras_tuner/engine/base_tuner.py:176, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     173         continue
#     175     self.on_trial_begin(trial)
# --> 176     self.run_trial(trial, *fit_args, **fit_kwargs)
#     177     self.on_trial_end(trial)
#     178 self.on_search_end()
#
# File /opt/app-root/lib64/python3.9/site-packages/keras_tuner/tuners/hyperband.py:370, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     368     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     369     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 370 super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#
# File /opt/app-root/lib64/python3.9/site-packages/keras_tuner/engine/multi_execution_tuner.py:90, in MultiExecutionTuner.run_trial(self, trial, *fit_args, **fit_kwargs)
#      87 callbacks.append(model_checkpoint)
#      88 copied_fit_kwargs["callbacks"] = callbacks
# ---> 90 history = self._build_and_fit_model(trial, fit_args, copied_fit_kwargs)
#      91 for metric, epoch_values in history.history.items():
#      92     if self.oracle.objective.direction == "min":
#
# File /opt/app-root/lib64/python3.9/site-packages/keras_tuner/engine/tuner.py:149, in Tuner._build_and_fit_model(self, trial, fit_args, fit_kwargs)
#     131 """For AutoKeras to override.
#     132
#     133 DO NOT REMOVE this function. AutoKeras overrides the function to tune
#    (...)
#     146     The fit history.
#     147 """
#     148 model = self.hypermodel.build(trial.hyperparameters)
# --> 149 return model.fit(*fit_args, **fit_kwargs)
#
# File /opt/app-root/lib64/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /opt/app-root/lib64/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'fingerprint_prediction/activation/Relu' defined at (most recent call last):
#     File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/opt/app-root/lib64/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/opt/app-root/lib64/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib64/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/usr/lib64/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/usr/lib64/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/opt/app-root/lib64/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/opt/app-root/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/opt/app-root/lib64/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/opt/app-root/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/opt/app-root/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/opt/app-root/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_5479/3074484213.py", line 1, in <module>
#       tuner.search(train_ds, epochs=4, validation_data=validation_ds, callbacks=[stop_early])
#     File "/opt/app-root/lib64/python3.9/site-packages/keras_tuner/engine/base_tuner.py", line 176, in search
#       self.run_trial(trial, *fit_args, **fit_kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras_tuner/tuners/hyperband.py", line 370, in run_trial
#       super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras_tuner/engine/multi_execution_tuner.py", line 90, in run_trial
#       history = self._build_and_fit_model(trial, fit_args, copied_fit_kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras_tuner/engine/tuner.py", line 149, in _build_and_fit_model
#       return model.fit(*fit_args, **fit_kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/training.py", line 1023, in train_step
#       y_pred = self(x, training=True)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/training.py", line 561, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/sequential.py", line 413, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/functional.py", line 511, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/functional.py", line 668, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/engine/base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/layers/core/activation.py", line 59, in call
#       return self.activation(inputs)
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/activations.py", line 317, in relu
#       return backend.relu(
#     File "/opt/app-root/lib64/python3.9/site-packages/keras/backend.py", line 5369, in relu
#       x = tf.nn.relu(x)
# Node: 'fingerprint_prediction/activation/Relu'
# OOM when allocating tensor with shape[32,96,96,96] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node fingerprint_prediction/activation/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_12451]

# %% [markdown]
# ## Fit a model
#
# Fit the model with the optimal hyperparameters and train it on the data for a desired number of epochs. This training cycle will run for 9 epochs resulting in an accuracy around ~0.98 accuracy

# %%
epochs = 8

model = tuner.hypermodel.build(best_hps)
history = model.fit(
    train_ds,
    batch_size=batch_size,
    validation_data=validation_ds,
    epochs=epochs,
    workers=1,
    use_multiprocessing=False
)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))

# %% [markdown]
# ## Print the model layers

# %%
model.summary()

# %% [markdown]
# ## Evaluate the model
#
# Should get an accuracy around 0.96

# %%
model.evaluate(
    test_ds,
    batch_size=batch_size,
    verbose='auto',
    sample_weight=None,
    steps=None,
    callbacks=None,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False
)

# %% [markdown]
# # Save the model
#
# A SavedModel is a directory containing serialized signatures and the state needed to run them, including variable values and vocabularies.
#
# ```
# assets            directory contains files used by the TensorFlow graph
# keras_metadata.pb file
# saved_model.pb    file stores the actual TensorFlow program, or model, and a set of named signatures for tensor I/O
# variables         directory contains a standard training checkpoint
# ```
#
# There are 2 formats you can use to save an entire model to disk, the TensorFlow SavedModel format and the older Keras H5 format.
#
# For versioning, you typically generate several models made up of (code, data, config) that demands model versioning.
#
# `/parent-folder/project-name/VERSION_NUMBER/MAJOR.MINOR.PIPELINE.tf`
#
# Triton expects the following folder structure:
#
# `/parent-folder/project-name/VERSION_NUMBER/model.savedmodel`
#
# * `parent-folder` should be the root of s3 url, ex: `s3://bucket/parent-folder`

# %% [markdown]
# ## Save locally
#
# Triton MUST have the model artifacts as `model.savedmodel`

# %%
# SET model version MAJOR.MINOR
# %env VERSION=1
# %env LITE_VERSION=1.1

model_version = os.environ.get('VERSION', "1")
lite_version = os.environ.get('LITE_VERSION', "1.1")

# %%
# note: tf.saved_model.save(model, path_to_dir)
model_path = "../models/fingerprint/" + model_version + "/model.savedmodel"
model.save(model_path)

# %% [markdown]
# ## Convert to TensorFlow Lite model
#
# TensorFlow Lite is a set of tools that enables on-device machine learning by helping developers run their models on mobile, embedded, and edge devices.
#
# To use the trained model with on-device applications, first convert it to a smaller and more efficient model format called a TensorFlow Lite model. To continue exploration with TFLite models [see this tutorial from TensorFlow](https://www.tensorflow.org/lite/models/modify/model_maker/image_classification#simple_end-to-end_example).

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

tflite_path = "../models/fingerprint/" + lite_version

if not os.path.exists(tflite_path):
    os.makedirs(tflite_path)
    
# Save the model.
with open(tflite_path + "/model.tflite", 'wb') as f:
  f.write(tflite_model)

# %% [markdown]
# # Make a prediction

# %% [markdown]
# ## Load the full model

# %%
model_path = "../models/fingerprint/" + model_version + "/model.savedmodel"
model = keras.models.load_model(model_path)

# %% [markdown]
# ### Load a new fingerprint

# %% [markdown]
# ### Convert the image

# %%
# select random images
import random

samples_path = scratch_path + '/real/'
file_list = os.listdir(samples_path)
print('Files in path: ' + str(len(file_list)))

test_image = random.choice(file_list)
print('Selected: ' + test_image)

# loads an image into PIL format.
img = tf.keras.utils.load_img(
    samples_path + test_image,
    color_mode="grayscale",
    target_size=(img_height, img_width),
    interpolation='nearest',
)

plt.imshow(img, cmap='gray')

# converts a PIL image instance to a numpy array
img_array = tf.keras.utils.img_to_array(img)
print("shape:",img_array.shape)
print("shape:",img_array.dtype)
print("shape:",img_array.size)

img_array = tf.expand_dims(img_array, 0)

# %% [markdown]
# ### Predict

# %%
# perform a prediction on the new fingerprint
predictions = model.predict(img_array)

# %%
import numpy as np

score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
